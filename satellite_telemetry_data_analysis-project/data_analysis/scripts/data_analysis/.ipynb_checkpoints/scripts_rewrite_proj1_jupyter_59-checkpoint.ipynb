# %%
# importing the created gps data and detph data

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import matplotlib.lines as mlines
# for the depth graph
import plotly.graph_objects as go

# %%
# To run with terminal OR jupyter notebook:

DATACLEANINGRESULTS_FOLDER = "dataCleaningResults"
DATACLEANINGRESULTS_FOLDER_ITENS = os.listdir(DATACLEANINGRESULTS_FOLDER)# ("data_analysis/dataCleaningResults")

# %%
def addDataFromCsv(filename):
    currentFileCsv = DATACLEANINGRESULTS_FOLDER + '/' + filename
    df = pd.read_csv(currentFileCsv)
    return df

# %%
#for file in DATACLEANINGRESULTS_FOLDER_ITENS:
    #print(file)

# %%
gpsT1 = "reliableGpsDf_lastOne_Tag_710333a_2021_Feb.csv"
gpsT2 = "reliableGpsDf_lastOne_Tag_710348a_2021_Feb.csv"
depthT1 = "depthDataDf_lastOne_Tag_710333a_2021_Feb.csv"
depthT2 = "depthDataDf_lastOne_Tag_710348a_2021_Feb.csv"

# %%
gpsDfT1 = addDataFromCsv(gpsT1)
gpsDfT2 = addDataFromCsv(gpsT2)
depthDfT1 = addDataFromCsv(depthT1)
depthDfT2 = addDataFromCsv(depthT2)

# %%
#depthDfT1.head(10)

# %%
depthDfT1['Underwater Percentage'].mean()
# Out:
# 88.62694521604939

# %%
depthDfT1['Dive Count'].mean()
# Out:
# 23.066743827160494

# %%
depthDfT1['Average Dive Duration'].mean()
# Out:
# 1817.6296296296296

# %%
depthDfT1['Maximum Dive Depth'].mean()
# Out:
# 36.45293209876543

# %%
depthDfT1['Layer 1 Percentage'].mean()
# Out:
# 34.928725694444445

# %%
tag = 7103

# %%
#Replace invalid values with None in Pandas DataFrame

# %%
#i=0
#listEmpty = []
#while i < len(depthDfT1['Layer 1 Percentage']):
    #value = str(depthDfT1['Layer 1 Percentage'][i])
    #if value == '0.391':
        #noneValue = depthDfT1.replace(value, pd.NA, inplace=True)
        #listEmpty.append(noneValue)
    #else:
        #listEmpty.append(depthDfT1['Layer 1 Percentage'][i])
    #i+=1
#print(listEmpty)

# %%
# used dataframes:

# %%
#gpsDfT1 = addDataFromCsv(gpsT1)
#gpsDfT2 = addDataFromCsv(gpsT2)
#percentageSignDepthDfT1 = addDataFromCsv(percentageSignDepthT1)
#percentageSignDepthDfT2 = addDataFromCsv(percentageSignDepthT2)

# %% [markdown]
# 1. Function to return all the variables I need from the Depth data
#
#     1.1 Looping through Layer
#
#     1.2 Assigning variables for max and min float values in layer percentage
#
#     1.3 Converted Decimals of Layer to Percentage just to use in the hovertext, for visualization, it don't work with the markers
#
#     1.4 returning Layer values (float), minimum Layer value (float), maximum Layer value (float), Layer values in Percentage

# %%
#depthDfT1['Layer 1 Percentage']

# %%
#def noneValueWillNotAppears(layerFloatPercentageColumnWanted, depthData): # 1
    #i=0
    #layerDepthWithNoneValues = []
    #while i < len(depthData[layerFloatPercentageColumnWanted]):
        #value = str(depthData[layerFloatPercentageColumnWanted][i])
        #if value == '0.391':
            #noneValue = depthData.replace(value, pd.NA, inplace=True)
            #layerDepthWithNoneValues.append(noneValue)
        #else:
            #layerDepthWithNoneValues.append(depthData[layerFloatPercentageColumnWanted][i])
        #i+=1
    #print(layerDepthWithNoneValues)
    #return layerDepthWithNoneValues

# %%
#def minmax(data):
    #_min = data[0]
    #_max = data[0]
    #for i in range(len(data)):
        #if _min > data[i]: 
            #_min = data[i]
        #if _max < data[i]:
            #_max = data[i]
    #return (_min, _max)

# %%
def noneValueWillNotAppearsWithMinAnMax(layerFloatPercentageColumnWanted, depthData): # 1
    i=0
    layerDepthWithNoneValues = []
    layerDepthsWithPercentageSigns = []
    _min = depthData[layerFloatPercentageColumnWanted][0]
    _max = depthData[layerFloatPercentageColumnWanted][0]
    #minPercLay = min(feature for feature in depthData[layerFloatPercentageColumnWanted]) # 1.2
    #maxPercLay = max(feature for feature in depthData[layerFloatPercentageColumnWanted]) # 1.2
    while i < len(depthData[layerFloatPercentageColumnWanted]):
        if _min <= 0.391:
            _min = depthData[layerFloatPercentageColumnWanted][i]
            if _min > depthData[layerFloatPercentageColumnWanted][i]:
                _min = depthData[layerFloatPercentageColumnWanted][i]
        if _max < depthData[layerFloatPercentageColumnWanted][i]:
            _max = depthData[layerFloatPercentageColumnWanted][i]
        value = str(depthData[layerFloatPercentageColumnWanted][i])
        if value == '0.391':
            noneValue = depthData.replace(value, pd.NA, inplace=True)
            layerDepthWithNoneValues.append(noneValue)
            percSymbol = '{:.2f}%'.format(0)
            layerDepthsWithPercentageSigns.append(percSymbol)
        else:
            layerDepthWithNoneValues.append(depthData[layerFloatPercentageColumnWanted][i])
            percSymbol = '{:.2f}%'.format(depthData[layerFloatPercentageColumnWanted][i])
            layerDepthsWithPercentageSigns.append(percSymbol)
        i+=1
    #print(layerDepthWithNoneValues)
    
    print(_min)
    print(_max)
    #print(type(_min))
    #print(type(_max))
    #print(layerDepthsWithPercentageSigns)
    return layerDepthWithNoneValues, _min, _max, layerDepthsWithPercentageSigns

# %%
depthsWithNoneValuesT1L1, minValueT1L1, maxValueT1L1, depthsWithPercentageSignsT1L1 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 1 Percentage',depthDfT1
)
depthsWithNoneValuesT1L2, minValueT1L2, maxValueT1L2, depthsWithPercentageSignsT1L2 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 2 Percentage',depthDfT1
)
depthsWithNoneValuesT1L3, minValueT1L3, maxValueT1L3, depthsWithPercentageSignsT1L3 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 3 Percentage',depthDfT1
)
depthsWithNoneValuesT1L4, minValueT1L4, maxValueT1L4, depthsWithPercentageSignsT1L4 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 4 Percentage',depthDfT1
)
depthsWithNoneValuesT1L5, minValueT1L5, maxValueT1L5, depthsWithPercentageSignsT1L5 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 5 Percentage',depthDfT1
)
depthsWithNoneValuesT1L6, minValueT1L6, maxValueT1L6, depthsWithPercentageSignsT1L6 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 6 Percentage',depthDfT1
)
depthsWithNoneValuesT1L7, minValueT1L7, maxValueT1L7, depthsWithPercentageSignsT1L7 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 7 Percentage',depthDfT1
)
depthsWithNoneValuesT1L8, minValueT1L8, maxValueT1L8, depthsWithPercentageSignsT1L8 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 8 Percentage',depthDfT1
)
depthsWithNoneValuesT1L9, minValueT1L9, maxValueT1L9, depthsWithPercentageSignsT1L9 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 9 Percentage',depthDfT1
)
depthsWithNoneValuesT1L10, minValueT1L10, maxValueT1L10, depthsWithPercentageSignsT1L10 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 10 Percentage',depthDfT1
)
# Out:
# 6.641
# 99.609
# 14.453
# 98.047
# 13.672
# 99.609
# 2.734
# 99.609
# 1.953
# 78.516
# 1.172
# 68.359
# 1.953
# 75.391
# 1.172
# 45.703
# 1.172
# 23.828
# 1.172
# 19.141

# %%
depthsWithNoneValuesT2L1, minValueT2L1, maxValueT2L1, depthsWithPercentageSignsT2L1 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 1 Percentage',depthDfT2
)
depthsWithNoneValuesT2L2, minValueT2L2, maxValueT2L2, depthsWithPercentageSignsT2L2 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 2 Percentage',depthDfT2
)
depthsWithNoneValuesT2L3, minValueT2L3, maxValueT2L3, depthsWithPercentageSignsT2L3 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 3 Percentage',depthDfT2
)
depthsWithNoneValuesT2L4, minValueT2L4, maxValueT2L4, depthsWithPercentageSignsT2L4 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 4 Percentage',depthDfT2
)
depthsWithNoneValuesT2L5, minValueT2L5, maxValueT2L5, depthsWithPercentageSignsT2L5 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 5 Percentage',depthDfT2
)
depthsWithNoneValuesT2L6, minValueT2L6, maxValueT2L6, depthsWithPercentageSignsT2L6 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 6 Percentage',depthDfT2
)
depthsWithNoneValuesT2L7, minValueT2L7, maxValueT2L7, depthsWithPercentageSignsT2L7 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 7 Percentage',depthDfT2
)
depthsWithNoneValuesT2L8, minValueT2L8, maxValueT2L8, depthsWithPercentageSignsT2L8 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 8 Percentage',depthDfT2
)
depthsWithNoneValuesT2L9, minValueT2L9, maxValueT2L9, depthsWithPercentageSignsT2L9 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 9 Percentage',depthDfT2
)
depthsWithNoneValuesT2L10, minValueT2L10, maxValueT2L10, depthsWithPercentageSignsT2L10 = noneValueWillNotAppearsWithMinAnMax(
    'Layer 10 Percentage',depthDfT2
)
# Out:
# 32.422
# 99.609
# 16.016
# 99.609
# 36.328
# 99.609
# 3.516
# 99.609
# 1.953
# 88.672
# 2.734
# 83.984
# 9.766
# 80.078
# 14.453
# 44.141
# 3.516
# 28.516
# 1.953
# 2.734

# %%
def generateGeoMap(
    turtleGpsDf, turtleDepthDf, layerDepthsWithNoneValues, 
    minPercLay, maxPercLay, 
    layerDepthsInPercentage, layerNumber, turtleTag
): # 3
    
    if turtleTag == '710333a':
        mapboxGeoLoc, mapboxZoom = {'lon':6.9, 'lat': 37.8}, 5
    elif turtleTag == '710348a':
        mapboxGeoLoc, mapboxZoom = {'lon':16.5, 'lat': 38.9}, 5
    else:
        mapboxGeoLoc, mapboxZoom = {'lon':13, 'lat': 38.4}, 5
        print(f"The Mapbox geolocation of this tagged turtle {turtleTag} has not been saved yet.")
        print(f"We are going to give it a longitude and latitude at {mapboxGeoLoc} and zoom of {mapboxZoom}")
    
    graphTitle = f'The occurrence of Loggerhead Sea Turtle Tag: {turtleTag} on Layer {layerNumber} deep'
    
    if layerNumber == 1:
        textOfMeters = 'Occurrences in Water Depths within the range of 0-5 Meters Deep'
        layerDepths = 'Layer 1 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 2:
        textOfMeters = 'Occurrences in Water Depths within the range of -6 to -10 Meters Deep'
        layerDepths = 'Layer 2 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 3:
        textOfMeters = 'Occurrences in Water Depths within the range of -11 to -20 Meters Deep'
        layerDepths = 'Layer 3 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 4:
        textOfMeters = 'Occurrences in Water Depths within the range of -21 to -30 Meters Deep'
        layerDepths = 'Layer 4 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 5:
        textOfMeters = 'Occurrences in Water Depths within the range of -31 to -40 Meters Deep'
        layerDepths = 'Layer 5 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 6:
        textOfMeters = 'Occurrences in Water Depths within the range of -41 to -50 Meters Deep'
        layerDepths = 'Layer 6 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 7:
        textOfMeters = 'Occurrences in Water Depths within the range of -51 to -70 Meters Deep'
        layerDepths = 'Layer 7 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 8:
        textOfMeters = 'Occurrences in Water Depths within the range of -71 to -90 Meters Deep'
        layerDepths = 'Layer 8 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 9:
        textOfMeters = 'Occurrences in Water Depths within the range of -91 to -110 Meters Deep'
        layerDepths = 'Layer 9 Percentage'
        my_set_max = maxPercLay
    if layerNumber == 10:
        textOfMeters = 'Occurrences in Water Depths within the range of -111 to -4095 Meters Deep'
        layerDepths = 'Layer 10 Percentage'
        my_set_max = maxPercLay + 10
        #'Loggerhead Sea Turtle Percentage of Occurrences in Water Depths within the range of -111 to -4095 Meters Deep'
    
    gomaptraceLayer = go.Figure(go.Scattermapbox(
                                    lat=turtleGpsDf['GPS Latitude'],
                                    lon=turtleGpsDf['GPS Longitude'],
                                    name = 'GPS Data Tracking Route',
                                    mode="markers+lines",
                                    marker = {'size': 2, 'color': 'rgb(201, 97, 161)'},
                                    # {'size': 2, 'color': 'red'}, # {'size': 8, 'color': 'yellow'}, # changed the size
                                    text = turtleGpsDf['Acquisition Time'],
                                    hoverinfo='text'
                                ))
    gomaptraceLayer.add_trace(go.Scattermapbox(
                                    lat=turtleDepthDf['Approx Depth AQ Time Latitude'],
                                    lon=turtleDepthDf['Approx Depth AQ Time Longitude'],
                                    name = 'Depth Approximate Location', #############
                                    mode = "markers", # "markers+lines",
                                    text = turtleDepthDf[layerDepths],
                                    marker = {        
                                        'colorscale': [[0, 'rgb(133, 230, 159)'], [0.5, 'rgb(78, 153, 98)'], [1, 'rgb(25, 0, 83)']],
                                        # [[0, 'green'], [0.5, 'rgb(78, 153, 98)'], [1, 'rgb(25, 0, 83)']],
                                        # [[0, 'green'], [0.5, 'blue'], [1, 'rgb(25, 0, 83)']],
                                        # [[0, 'rgb(255, 242, 0)'], [0.5, 'rgb(60, 163, 122)'], [1, 'rgb(25, 0, 83)']],
                                        # [[0, 'yellow'], [1, 'red']],# [[0, 'green'], [1, 'rgb(0, 0, 255)']],
                                        'color': turtleDepthDf[layerDepths],
                                        'cmax': maxPercLay, # float(maxPercLay.replace("%", "")),
                                        'cmin': minPercLay, # float(minPercLay.replace("%", "")),
                                        'size': turtleDepthDf[layerDepths],
                                        'sizemin':0.1,
                                        'sizemode': 'area',
                                        'sizeref': my_set_max / 6 **2, # float(maxPercLay.replace("%", "")) / 6 **2,
                                        'showscale':True,
                                        'colorbar': {
                                            'title': '% Occurrence', # including a colorbar
                                            'bgcolor': 'white',
                                            'titleside':'top',
                                            'x': 0,
                                            'y': 0.5,
                                            'tickformat': "0.%", # Formating tick labels to percentage on color bar
                                            'tickfont': {
                                                'color': '#000000',
                                                'family':"Open Sans",
                                                'size': 14
                                            }
                                        }
                                    },   
                                    hoverinfo='text',
                                    hovertext = layerDepthsInPercentage,  #100 * x), #(lambda x: '{0:1.2f}%'.format(x)#{:. n%} 
                                    opacity = 1
                                ))    
    
    gomaptraceLayer.update_layout(
        margin ={'l':0,'t':0,'b':0,'r':0},
        legend=dict(
            yanchor="top",
            y=0.99,
            xanchor="right", # "left", # "right"
            x=.99, # 0.16, # .99,#1.01
            ),
        legend_title_text=textOfMeters,
        showlegend=True, # change if you want to see the legend *
        #title={'text': textOfMeters, 'font':dict(size=18), 'y':0.9, 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},
        #font=dict(size=18), # family="Courier New, monospace", size=18), #color="RebeccaPurple"),
        mapbox = {
            'style': "stamen-terrain",
            'center': mapboxGeoLoc,
            'zoom': mapboxZoom})

    return gomaptraceLayer

# %%
t1gomaptraceLayer1 = generateGeoMap(
    gpsDfT1, 
    depthDfT1, 
    #'Layer 1 Percentage',
    #'Layer 1 - Water Depth within the range of 0-5 Meters Deep',
    depthsWithNoneValuesT1L1,    
    minValueT1L1, 
    maxValueT1L1, 
    depthsWithPercentageSignsT1L1, 
    1, '710333a'
)

# %%
t1gomaptraceLayer1.show()
# Out:
# <div>                            <div id="efe37f9c-7bbe-4c7f-b8c4-7106b712a666" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efe37f9c-7bbe-4c7f-b8c4-7106b712a666")) {                    Plotly.newPlot(                        "efe37f9c-7bbe-4c7f-b8c4-7106b712a666",                        [{"hoverinfo":"text","lat":[37.930044,37.930187,37.931116,37.931058,37.931116,37.931174,37.926526,37.921882,37.919837,37.919332,37.919043,37.919191,37.919105,37.919081,37.918549,37.918847,37.918878,37.919422,37.919326,37.918992,37.917318,37.917011,37.9174,37.919408,37.919192,37.91859,37.91846,37.917871,37.919938,37.920116,37.920155,37.920203,37.923794,37.922677,37.922227,37.922039,37.921612,37.920197,37.919218,37.918895,37.918295,37.917115,37.91665,37.902009,37.76
# ...

# %%
t2gomaptraceLayer1 = generateGeoMap(
    gpsDfT2, 
    depthDfT2, 
    #'Layer 1 Percentage',
    #'Layer 1 - Water Depth within the range of 0-5 Meters Deep',
    depthsWithNoneValuesT2L1,    
    minValueT2L1, 
    maxValueT2L1, 
    depthsWithPercentageSignsT2L1, 
    1, '710348a'
)

# %%
t2gomaptraceLayer1.show()
# Out:
# <div>                            <div id="e0fb1b9c-eecb-4ae7-a759-bb4f63b19fcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0fb1b9c-eecb-4ae7-a759-bb4f63b19fcc")) {                    Plotly.newPlot(                        "e0fb1b9c-eecb-4ae7-a759-bb4f63b19fcc",                        [{"hoverinfo":"text","lat":[37.928124,37.921919,37.919124,37.916251,37.897905,37.860106,37.853432,37.843246,37.843084,37.835522,37.826293,37.817057,37.817285,37.813053,37.811382,37.807962,37.806542,37.805733,37.803426,37.802173,37.799572,37.795035,37.79236,37.786791,37.779757,37.774692,37.766478,37.76069,37.755029,37.750005,37.745921,37.742606,37.740441,37.735725,37.732689,37.728181,37.724728,37.721828,37.717576,37.711544,37.708369,37.698781,37.69724,37.696195,37.
# ...

# %%
t1gomaptraceLayer10 = generateGeoMap(
    gpsDfT1, 
    depthDfT1, 
    depthsWithNoneValuesT1L10,    
    minValueT1L10, 
    maxValueT1L10, 
    depthsWithPercentageSignsT1L10, 
    10, '710333a'
)
t1gomaptraceLayer10.show()
# Out:
# <div>                            <div id="3444e570-a0f9-413f-a396-1be2c067b04b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3444e570-a0f9-413f-a396-1be2c067b04b")) {                    Plotly.newPlot(                        "3444e570-a0f9-413f-a396-1be2c067b04b",                        [{"hoverinfo":"text","lat":[37.930044,37.930187,37.931116,37.931058,37.931116,37.931174,37.926526,37.921882,37.919837,37.919332,37.919043,37.919191,37.919105,37.919081,37.918549,37.918847,37.918878,37.919422,37.919326,37.918992,37.917318,37.917011,37.9174,37.919408,37.919192,37.91859,37.91846,37.917871,37.919938,37.920116,37.920155,37.920203,37.923794,37.922677,37.922227,37.922039,37.921612,37.920197,37.919218,37.918895,37.918295,37.917115,37.91665,37.902009,37.76
# ...

# %%
t2gomaptraceLayer10 = generateGeoMap(
    gpsDfT2, 
    depthDfT2, 
    depthsWithNoneValuesT2L10,    
    minValueT2L10, 
    maxValueT2L10, 
    depthsWithPercentageSignsT2L10, 
    10, '710348a'
)
t2gomaptraceLayer10.show()
# Out:
# <div>                            <div id="89c0e534-c601-42e5-b70d-95e0b20a2257" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89c0e534-c601-42e5-b70d-95e0b20a2257")) {                    Plotly.newPlot(                        "89c0e534-c601-42e5-b70d-95e0b20a2257",                        [{"hoverinfo":"text","lat":[37.928124,37.921919,37.919124,37.916251,37.897905,37.860106,37.853432,37.843246,37.843084,37.835522,37.826293,37.817057,37.817285,37.813053,37.811382,37.807962,37.806542,37.805733,37.803426,37.802173,37.799572,37.795035,37.79236,37.786791,37.779757,37.774692,37.766478,37.76069,37.755029,37.750005,37.745921,37.742606,37.740441,37.735725,37.732689,37.728181,37.724728,37.721828,37.717576,37.711544,37.708369,37.698781,37.69724,37.696195,37.
# ...
