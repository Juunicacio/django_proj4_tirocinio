# %%
# importing the created gps data and detph data

# %%
import os
import pandas as pd

# %%
# To run with terminal OR jupyter notebook:

DATACLEANINGRESULTS_FOLDER = "dataCleaningResults"
DATACLEANINGRESULTS_FOLDER_ITENS = os.listdir(DATACLEANINGRESULTS_FOLDER)# ("data_analysis/dataCleaningResults")

# %%
def addDataFromCsv(filename):
    currentFileCsv = DATACLEANINGRESULTS_FOLDER + '/' + filename
    df = pd.read_csv(currentFileCsv)
    return df
    #df.sort_values("Acquisition Time", inplace = True)
    # shows top 10 rows
    #df.head(10)
    # do something

# %%
for file in DATACLEANINGRESULTS_FOLDER_ITENS:
    print(file)
# Out:
# 1_percentage_of_gps_data_across_qfp_position_categories__bar_chart.png
# 2_percentage_of_gps_data_across_qfp_position_categories__bar_chart.png
# allCleanedGpsDf_Tag_710333a_2021_Feb.csv
# allCleanedGpsDf_Tag_710348a_2021_Feb.csv
# allGpsDf_Tag_710333a_2021_Feb.csv
# allGpsDf_Tag_710348a_2021_Feb.csv
# depthDataDfWithApproxCoord_floatValues_Tag_710333a_2021_Feb.csv
# depthDataDfWithApproxCoord_floatValues_Tag_710333a_2021_Feb.json
# depthDataDfWithApproxCoord_floatValues_Tag_710348a_2021_Feb.csv
# depthDataDfWithApproxCoord_floatValues_Tag_710348a_2021_Feb.json
# depthDataDfWithApproxCoord_Tag_710333a_2021_Feb.csv
# depthDataDfWithApproxCoord_Tag_710348a_2021_Feb.csv
# depthDataDf_lastOne_Tag_710333a_2021_Feb.csv
# depthDataDf_lastOne_Tag_710348a_2021_Feb.csv
# depthDataDf_Tag_710333a_2021_Feb.csv
# depthDataDf_Tag_710348a_2021_Feb.csv
# depthDataSkyIlluminationAndFloatValues_Tag_710333a_2021_Feb.csv
# depthDataSkyIlluminationAndFloatValues_Tag_710348a_2021_Feb.csv
# depthDataWithApprxCoordDfWithSkyIllumination_Tag_710333a_2021_Feb.csv
# depthDataWithApprxCoordDfWithSkyIllumination_Tag_710348a_2021_Feb.csv
# loggerhead_sea_turtle_710333a_speeds_scatter.png
# loggerhead_sea_turtle_710333a_speeds_scatter_graph.png
# loggerhead_sea_turtle_710333a_speed_histogram_speed_histogram.png
# loggerhead_sea_turtle_710348a_speeds_scatter.png
# loggerhead_sea_turtle_710348a_speeds_scatter_graph.png
# loggerhead_sea_turtle_710348a_speed_histogram_speed_histogram.png
# noGpsDf_Tag_710333a_2021_Feb.csv
# noGpsDf_Tag_710348a_2021_Feb.csv
# noReliableGpsDf_bySpeed_Tag_710333a_2021_Feb.csv
# noReliableGpsDf_bySpeed_Tag_710348a_2021_Jan.csv
# reliableGpsDfWithSkyIlluminationAndKmHColumn_Tag_710333a_2021_Feb.csv
# reliableGpsDfWithSkyIlluminationAndKmHColumn_Tag_710348a_2021_Feb.csv
# reliableGpsDfWithSkyIllumination_Tag_710333a_2021_Feb.csv
# reliableGpsDfWithSkyIllumination_Tag_710348a_2021_Feb.csv
# reliableGpsDf_bySpeed_Tag_710333a_2021_Feb.csv
# reliableGpsDf_bySpeed_Tag_710333a_2021_Feb.json
# reliableGpsDf_bySpeed_Tag_710348a_2021_Feb.csv
# reliableGpsDf_bySpeed_Tag_710348a_2021_Feb.json
# reliableGpsDf_lastOne_Tag_710333a_2021_Feb.csv
# reliableGpsDf_lastOne_Tag_710348a_2021_Feb.csv
# remainingDataDf_Tag_710333a_2021_Feb.csv
# remainingDataDf_Tag_710348a_2021_Feb.csv
# _gps_positions_recorded_by_710333a_transmitter_tag_graph.png
# _gps_positions_recorded_by_710348a_transmitter_tag_graph.png

# %%
gpsT1 = "reliableGpsDfWithSkyIllumination_Tag_710333a_2021_Feb.csv"

# %%
gpsT2 = "reliableGpsDfWithSkyIllumination_Tag_710348a_2021_Feb.csv"

# %%
depthT1 = "depthDataWithApprxCoordDfWithSkyIllumination_Tag_710333a_2021_Feb.csv"

# %%
depthT2 = "depthDataWithApprxCoordDfWithSkyIllumination_Tag_710348a_2021_Feb.csv"

# %%
# importing gps data of each turtle

# %%
gpsDfT1 = addDataFromCsv(gpsT1)

# %%
gpsDfT2  = addDataFromCsv(gpsT2)

# %%
# importing depth data of each turtle

# %%
depthDfT1 = addDataFromCsv(depthT1)

# %%
depthDfT2  = addDataFromCsv(depthT2)

# %%
gpsDfT1.head(10)
# Out:
#    Reliable Speed ID  All GPS's Track ID     Acquisition Time  \
# 0                  1                  25  2020.07.09 23:00:09
# 1                  2                  26  2020.07.09 23:30:12
# 2                  3                  27  2020.07.10 00:30:08
# 3                  4                  28  2020.07.10 01:00:08
# 4                  5                  29  2020.07.10 01:30:07
# 5                  6                  30  2020.07.10 02:00:08
# 6                  7                  31  2020.07.10 03:02:21
# 7                  8                  32  2020.07.10 03:43:05
# 8                  9                  33  2020.07.10 05:12:33
# 9                 10                  34  2020.07.10 05:34:02
#
#   Acquisition Start Time         GPS Fix Time           GPS Fix Attempt  \
# 0    2020.07.09 23:00:00  2020.07.09 23:00:09  Resolved QFP (Uncertain)
# 1    2020.07.09 23:30:00  2020.07.09 23:30:12              Resolved QFP
# 2    2020.07.10 00:30:00  2020.07.10 00:30:08              Resolved QFP
# 3    2020.07.10 01:00:00  2020.07.10 01:00:08              Resolved QFP
# 4    2020.07.10 01:30:00  2020.07.10 01:30:07              Resolved QFP
# 5    2020.07.10 02:00:00  2020.07.10 02:00:08              Resolved QFP
# 6    2020.07.10 03:00:00  2020.07.10 03:02:21              Resolved QFP
# 7    2020.07.10 03:30:00  2020.07.10 03:43:05              Resolved QFP
# 8    2020.07.10 05:00:00  2020.07.10 05:12:33              Resolved QFP
# 9    2020.07.10 05:30:00  2020.07.10 05:34:02              Resolved QFP
#
#    GPS Latitude  GPS Longitude  Distance (m)  Time (s)  Speed m/s  \
# 0     37.930044      16.068138      0.000000       0.0   0.000000
# 1     37.930187      16.068178     16.257208    1803.0   0.009017
# 2     37.931116      16.069576    160.431667    3596.0   0.044614
# 3     37.931058      16.069576      6.437720    1800.0   0.003577
# 4     37.931116      16.069615      7.293834    1799.0   0.004054
# 5     37.931174      16.069640      6.802561    1801.0   0.003777
# 6     37.926526      16.070751    525.070436    3733.0   0.140656
# 7     37.921882      16.070621    515.587689    2444.0   0.210961
# 8     37.919837      16.048652   1944.953617    5368.0   0.362324
# 9     37.919332      16.048329     62.836971    1289.0   0.048749
#
#           Time (h)  Daylight                Position Dawn time  \
# 0  0 days 00:00:00     False  2020-07-09 03:10:20.485364+00:00
# 1  0 days 00:30:03     False  2020-07-09 03:10:20.445827+00:00
# 2  0 days 00:59:56     False  2020-07-10 03:11:01.436174+00:00
# 3  0 days 00:30:00     False  2020-07-10 03:11:01.448234+00:00
# 4  0 days 00:29:59     False  2020-07-10 03:11:01.426810+00:00
# 5  0 days 00:30:01     False  2020-07-10 03:11:01.408747+00:00
# 6  0 days 01:02:13     False  2020-07-10 03:11:02.108342+00:00
# 7  0 days 00:40:44      True  2020-07-10 03:11:03.104918+00:00
# 8  0 days 01:29:28      True  2020-07-10 03:11:08.805090+00:00
# 9  0 days 00:21:29      True  2020-07-10 03:11:08.987604+00:00
#
#                  Position Dusk Time  Data Month  Data Year Months by Year
# 0  2020-07-09 18:51:23.473037+00:00           7       2020      July 2020
# 1  2020-07-09 18:51:23.493220+00:00           7       2020      July 2020
# 2  2020-07-10 18:50:57.628461+00:00           7       2020      July 2020
# 3  2020-07-10 18:50:57.616466+00:00           7       2020      July 2020
# 4  2020-07-10 18:50:57.619104+00:00           7       2020      July 2020
# 5  2020-07-10 18:50:57.625101+00:00           7       2020      July 2020
# 6  2020-07-10 18:50:56.397354+00:00           7       2020      July 2020
# 7  2020-07-10 18:50:55.468353+00:00           7       2020      July 2020
# 8  2020-07-10 18:51:00.316514+00:00           7       2020      July 2020
# 9  2020-07-10 18:51:00.289615+00:00           7       2020      July 2020

# %%
#depthDfT1.head(10)

# %%
# m/s is the unit of speed which is expressed in terms of meters and seconds
# To convert a speed from m/s to km/h, we multiply it by the conversion factor of 3600/1000 or 18/5.

# %%
# Average of Turtle 1 speed in m/s

# %%
speedInMsT1 = gpsDfT1['Speed m/s'].mean()
print(speedInMsT1)
# Out:
# 0.26814161013418664

# %%
# Average of Turtle 1 speed in k/h

# %%
speedInKmT1 = speedInMsT1 * 3600/1000
print(speedInKmT1)
# Out:
# 0.9653097964830719

# %%
# Average of Turtle 2 speed in m/s

# %%
speedInMsT2 = gpsDfT2['Speed m/s'].mean()
print(speedInMsT2)
# Out:
# 0.25795600612863484

# %%
# Average of Turtle 2 speed in k/h

# %%
speedInKmT2 = speedInMsT2 * 3600/1000
print(speedInKmT2)
# Out:
# 0.9286416220630854

# %%
gpsDfT1['Speed m/s'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gpsDfT2['Speed m/s'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def msToKm(x):
    return x * 3600/1000
def changeColumnValueCreatingAnotherColumn(df, columnName, newColumnName):
    df[newColumnName] = df[columnName].apply(msToKm)
    return df

# %%
# adding new column to the dataframe with speed in km/h

# %%
changeColumnValueCreatingAnotherColumn(gpsDfT1, 'Speed m/s', 'Speed km/h')
# Out:
#       Reliable Speed ID  All GPS's Track ID     Acquisition Time  \
# 0                     1                  25  2020.07.09 23:00:09
# 1                     2                  26  2020.07.09 23:30:12
# 2                     3                  27  2020.07.10 00:30:08
# 3                     4                  28  2020.07.10 01:00:08
# 4                     5                  29  2020.07.10 01:30:07
# ...                 ...                 ...                  ...
# 3210               3244                3268  2021.02.10 19:28:58
# 3211               3245                3269  2021.02.10 22:42:32
# 3212               3246                3270  2021.02.11 02:28:20
# 3213               3247                3271  2021.02.11 05:55:38
# 3214               3248                3272  2021.02.11 06:00:10
#
#      Acquisition Start Time         GPS Fix Time           GPS Fix Attempt  \
# 0       2020.07.09 23:00:00  2020.07.09 23:00:09  Resolved QFP (Uncertain)
# 1       2020.07.09 23:30:00  2020.07.09 23:30:12              Resolved QFP
# 2       2020.07.10 00:30:00  2020.07.10 00:30:08              Resolved QFP
# 3       2020.07.10 01:00:00  2020.07.10 01:00:08              Resolved QFP
# 4       2020.07.10 01:30:00  2020.07.10 01:30:07              Resolved QFP
# ...                     ...                  ...                       ...
# 3210    2021.02.10 19:00:00  2021.02.10 19:28:58              Resolved QFP
# 3211    2021.02.10 22:00:00  2021.02.10 22:42:32              Resolved QFP
# 3212    2021.02.11 02:00:00  2021.02.11 02:28:20              Resolved QFP
# 3213    2021.02.11 05:00:00  2021.02.11 05:55:38              Resolved QFP
# 3214    2021.02.11 06:00:00  2021.02.11 06:00:10              Resolved QFP
#
#       GPS Latitude  GPS Longitude  Distance (m)  Time (s)  Speed m/s  \
# 0        37.930044      16.068138      0.000000       0.0   0.000000
# 1        37.930187      16.068178     16.257208    1803.0   0.009017
# 2        37.931116      16.069576    160.431667    3596.0   0.044614
# 3        37.931058      16.069576      6.437720    1800.0   0.003577
# 4        37.931116      16.069615      7.293834    1799.0   0.004054
# ...            ...            ...           ...       ...        ...
# 3210     38.754772      11.809630   2006.649120   12816.0   0.156574
# 3211     38.741873      11.821516   1765.808613   11614.0   0.152041
# 3212     38.727643      11.821051   1580.195674   13548.0   0.116637
# 3213     38.720644      11.825379    863.320601   12438.0   0.069410
# 3214     38.720648      11.825217     14.095488     272.0   0.051822
#
#              Time (h)  Daylight                Position Dawn time  \
# 0     0 days 00:00:00     False  2020-07-09 03:10:20.485364+00:00
# 1     0 days 00:30:03     False  2020-07-09 03:10:20.445827+00:00
# 2     0 days 00:59:56     False  2020-07-10 03:11:01.436174+00:00
# 3     0 days 00:30:00     False  2020-07-10 03:11:01.448234+00:00
# 4     0 days 00:29:59     False  2020-07-10 03:11:01.426810+00:00
# ...               ...       ...                               ...
# 3210  0 days 03:33:36     False  2021-02-10 05:41:48.452922+00:00
# 3211  0 days 03:13:34     False  2021-02-10 05:41:44.653276+00:00
# 3212  0 days 03:45:48     False  2021-02-11 05:40:39.612505+00:00
# 3213  0 days 03:27:18      True  2021-02-11 05:40:38.076520+00:00
# 3214  2021-02-11 17:13:44.977153+00:00           2       2021  February 2021
#
#       Speed km/h
# 0       0.000000
# 1       0.032460
# 2       0.160610
# 3       0.012875
# 4       0.014596
# ...          ...
# 3210    0.563665
# 3211    0.547349
# 3212    0.419893
# 3213    0.249876
# 3214    0.186558
#
# [3215 rows x 19 columns]

# %%
gpsDfT1['Speed km/h'].mean()
# Out:
# 0.9653097964830718

# %%
gpsDfT2['Speed km/h'].mean()
# Out:
# 0.9286416220630853

# %%
import matplotlib.pyplot as plt

# %%
# Generate data on commute times.
size, scale = 1000, 10

# %%
commutes1 = gpsDfT1['Speed m/s']

commutes1.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Commute Times for 1,000 Commuters')
plt.xlabel('Counts')
plt.ylabel('Commute Time')
plt.grid(axis='y', alpha=0.75)

# %%
commutes2 = gpsDfT2['Speed m/s']

commutes2.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Commute Times for 1,000 Commuters')
plt.xlabel('Counts')
plt.ylabel('Commute Time')
plt.grid(axis='y', alpha=0.75)

# %%
# Sample of normal distributions TURTLE 1

# %%
# Speed m/s

# %%
means = 10, 20
stdevs = 4, 2
distMsT1 = gpsDfT1['Speed m/s']
distMsT1.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
# min     0.00
# max     1.08
# mean    0.27
# std     0.18
# Name: Speed m/s, dtype: float64

# %%
# Speed km/h

# %%
means = 10, 20
stdevs = 4, 2
distKhT1 = gpsDfT1['Speed km/h']
distKhT1.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
# min     0.00
# max     3.89
# mean    0.97
# std     0.65
# Name: Speed km/h, dtype: float64

# %%
# Sample of normal distributions TURTLE 2

# %%
# Speed m/s

# %%
means = 10, 20
stdevs = 4, 2
distMsT2 = gpsDfT2['Speed m/s']
distMsT2.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
# min     0.00
# max     0.94
# mean    0.26
# std     0.15
# Name: Speed m/s, dtype: float64

# %%
# Speed km/h

# %%
means = 10, 20
stdevs = 4, 2
distKhT2 = gpsDfT2['Speed km/h']
distKhT2.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
# min     0.00
# max     3.39
# mean    0.93
# std     0.55
# Name: Speed km/h, dtype: float64

# %%
fig, ax = plt.subplots()
distMsT1.plot.kde(ax=ax, legend=False, title='Histogram: A vs. B')
distMsT1.plot.hist(density=True, ax=ax)
ax.set_ylabel('Probability')
ax.grid(axis='y')
ax.set_facecolor('#d8dcd6')

# %%
# Sample of both turtle normal distributions
means = 10, 20
stdevs = 4, 2
distBothMs = pd.DataFrame({ 'T1 Speed m/s': gpsDfT1['Speed m/s'], 'T2 Speed m/s': gpsDfT2['Speed m/s']})
distBothMs.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
#       T1 Speed m/s  T2 Speed m/s
# min           0.00          0.00
# max           1.08          0.94
# mean          0.27          0.26
# std           0.18          0.15

# %%
# Sample of both turtle normal distributions
#means = 10, 20
#stdevs = 4, 2
distBothKh = pd.DataFrame({ 'T1 Speed km/h': gpsDfT1['Speed km/h'], 'T2 Speed km/h': gpsDfT2['Speed km/h']})
distBothKh.agg(['min', 'max', 'mean', 'std']).round(decimals=2)
# Out:
#       T1 Speed km/h  T2 Speed km/h
# min            0.00           0.00
# max            3.89           3.39
# mean           0.97           0.93
# std            0.65           0.55

# %%
#fig, ax = plt.subplots()
#distBothKh.plot.kde(ax=ax, legend=True, title='Histogram')
#distBothMs.plot.hist(density=True, ax=ax)
#ax.set_ylabel('Probability')
#ax.grid(axis='y')
#ax.set_facecolor('#d8dcd6')

# %%
fig, ax = plt.subplots()
distBothKh.plot(ax=ax, legend=True, title='Histogram')
ax.set_ylabel('Speed km/h')
ax.grid(axis='y')

# %%
#ms = data['Speed m/s']
km = gpsDfT1['Speed km/h']
n, bins, patches = plt.hist(km, 30, facecolor='gray', align='mid')
plt.xlim(xmin=6.5, xmax = 4)
#pylab.rc("axes", linewidth=8.0)
#pylab.rc("lines", markeredgewidth=2.0) 
plt.xlabel('H mag', fontsize=14)
plt.ylabel('# of targets', fontsize=14)
#pylab.xticks(fontsize=15)
#pylab.yticks(fontsize=15)
plt.grid(True)
#plt.savefig('hmag_histogram.eps', facecolor='w', edgecolor='w', format='eps')
plt.show()

# %%
lower_limit,upper_limit = 0.1, 4

# %%
#f ,ax = plt.subplots(1,2,figsize = (30, 13),gridspec_kw={'width_ratios': [5, 1]})
#gpsDfT1['Speed km/h'].plot(ax = ax[0], linewidth = 2.5)
#ylim = [lower_limit,upper_limit]
#ax[0].set_ylim(ylim)
#ax[1].hist(data,normed =1, bins = num_bin, color = gpsDfT1['Daylight'] ,alpha = 1) 
#ax[1].set_ylim(ylim)

# %%
#plt.scatter(gpsDfT1['Speed km/h'], gpsDfT1['Acquisition Time'], c=gpsDfT1['Daylight'], ec='k')
#plt.show()

# %%
plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight'], ec='k')
plt.show()

# %%
scatter = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight'])#, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
#plt.legend(handles = [c])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
scatter = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight'])#, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.show()

# %%
import numpy as np

# %%
def buildScatterGraph(df, c1, c2, c3):
    sc = plt.scatter(df[c1], df[c2], s=size, c=df[c3], edgecolors='none')

    lp = lambda i: plt.plot([],color=sc.cmap(sc.norm(i)), ms=np.sqrt(size), mec="none",
                            label="Feature {:g}".format(i), ls="", marker="o")[0]
    print(lp)
    print(c3)
    handles = [lp(i) for i in np.unique(df[c3])]
    print(handles)
    plt.legend(handles=handles)
    plt.show()

# %%
buildScatterGraph(gpsDfT1, 'Data Month', 'Speed km/h', 'Daylight')
# Out:
# <function buildScatterGraph.<locals>.<lambda> at 0x00000233A4844160>
# Daylight
# [<matplotlib.lines.Line2D object at 0x0000023393732EE0>, <matplotlib.lines.Line2D object at 0x00000233A4846340>]

# %%
#from matplotlib.lines import Line2D
#custom_lines = [Line2D([0], [0], color=cmap(0.), lw=4),
                #Line2D([0], [0], color=cmap(.5), lw=4),
                #Line2D([0], [0], color=cmap(1.), lw=4)]

#fig, ax = plt.subplots()
#lines = ax.plot(data)
#ax.legend(custom_lines, ['Cold', 'Medium', 'Hot'])

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])

scatter = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']!= True, cmap=cmap)#, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.show()

#plt.yticks([1.0, 0.0], ["True",
                        #"False"])
#plt.scatter(x = data3.index, y= data3, c=(data3 != True).astype(float), marker='d', cmap=cmap)#plt.cm.get_cmap('RdBu'))

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])

scatter = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.legend(gpsDfT1['Daylight']== True)
plt.show()

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.show()

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.2)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)
plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
plt.show()

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(gpsDfT2['Data Month'], gpsDfT2['Speed km/h'], c=gpsDfT2['Daylight']!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(gpsDfT2['Data Month'], gpsDfT2['Speed km/h'], c=gpsDfT2['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.2)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)
plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
plt.show()

# %%
# Scatter Masked

# %%
from matplotlib.pyplot import figure
import matplotlib.colors as clrs
import matplotlib.lines as mlines
x,y = gpsDfT1['Data Month'], gpsDfT1['Speed km/h']
#fig, ax = plt.subplots()
fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
#figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.2)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x!= None)
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
meanLine = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Average Speed = {y.mean()}')

legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
legend2 = plt.legend(handles=[meanLine], loc=2)
plt.gca().add_artist(legend1)
plt.show()

# %%
x,y,c = gpsDfT2['Data Month'], gpsDfT2['Speed km/h'], gpsDfT2['Daylight']
#fig, ax = plt.subplots()
fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
#figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(x,y, c=c!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(x,y, c=c== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.2)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x!= None)
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
meanLine = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Average Speed = {y.mean()} km/h')

legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
legend2 = plt.legend(handles=[meanLine], loc=2)
plt.gca().add_artist(legend1)
plt.show()

# %%
x,y = gpsDfT1['Data Month'], gpsDfT1['Speed km/h']
#fig, ax = plt.subplots()
fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
#figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.5)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x)
y_max = [np.max(y)]*len(x)
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
maxLine = plt.plot(y_max, '-', label="Average Speed", color='red')

# Create legend
meanLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Estimated Average Speed = {round(y.mean(), 2)} km/h')
maxLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='red', marker='_',
                          markersize=15, label=f'Estimated Maximum Speed = {round(y.max(), 2)} km/h')

legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
legend2 = plt.legend(bbox_to_anchor=(.25, 1),handles=[meanLineLegend, maxLineLegend], loc=2)
plt.gca().add_artist(legend1)
plt.show()

# %%
tag = 7103

# %%
x,y = gpsDfT1['Data Month'], gpsDfT1['Speed km/h']
#fig, ax = plt.subplots()
fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
#figure(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')
cmap = clrs.ListedColormap(['blue', 'yellow'])
scatter1 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']!= True, cmap=cmap, ec='k')
scatter2 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], c=gpsDfT1['Daylight']== True, cmap=cmap, ec='k')
plt.xlabel('Research Months')
plt.ylabel('Speed km/h')
plt.ylim(ymin=0, ymax = 4.5)
plt.xlim(xmax = 12.5)
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x)
y_max = [np.max(y)]*len(x)
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
maxLine = plt.plot(y_max, '-', label="Average Speed", color='red')

# Create legend
meanLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Estimated Average Speed = {round(y.mean(), 2)} km/h')
maxLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='red', marker='_',
                          markersize=15, label=f'Maximum Speed = {round(y.max(), 2)} km/h')

legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
legend2 = plt.legend(bbox_to_anchor=(0., 1),handles=[meanLineLegend, maxLineLegend], loc=2)
plt.gca().add_artist(legend1)
title = f"Loggerhead Sea Turtle {tag} Speeds"
titleCont = " in Km/h"

plt.title(title+titleCont, fontdict={'fontsize': 16, 'fontweight': 'medium'}, loc='center')
plt.show()

# %%
gpsDfT1['Data Month'] = gpsDfT1['Data Month'].astype('str')
print(len(gpsDfT1['Data Month']))
# Out:
# 3215

# %%
acquisitionTimes = gpsDfT1[['Acquisition Time']].to_numpy()
months = gpsDfT1[['Data Month']].to_numpy()
i=0
j = months[0]
firstDayOfMonth = []
toBeKeyOfMonths = []
firstDayOfMonth.append(acquisitionTimes[0])
toBeKeyOfMonths.append(months[0])
#print(len(acquisitionTimes))
while i < (len(acquisitionTimes)):    
    #print(months[i])#8
    #print(j)#7
    if months[i] != j:
        nextMonthaqcTime = acquisitionTimes[i]
        #print(nextMonthaqcTime)
        firstDayOfMonth.append(nextMonthaqcTime)
        j = months[i]
        toBeKeyOfMonths.append(j)
    if i == len(acquisitionTimes)-1:
        #print(i)
        nextMonthaqcTime = acquisitionTimes[i]
        #print(nextMonthaqcTime)
        firstDayOfMonth.append(nextMonthaqcTime)
        #j = months[i]
    i+=1
#print(firstDayOfMonth)
#print(toBeKeyOfMonths)
#print(len(firstDayOfMonth))
#print(len(toBeKeyOfMonths))
tripTimes = []
#tripTimes.append(0)
i=1
while i < (len(firstDayOfMonth)):
    previous = i-1
    #print(firstDayOfMonth[i])
    t1 = pd.to_datetime(firstDayOfMonth[previous], format='%Y.%m.%d %H:%M:%S') #remove the brackets of the values in the column
    t2 = pd.to_datetime(firstDayOfMonth[i], format='%Y.%m.%d %H:%M:%S') #remove the brackets of the values in the column
    
    #t1Stamp = dt.datetime.strptime(t1, '%Y.%m.%d %H:%M:%S').timestamp()
    #print(t1Stamp)
    subTime = t2-t1
    #print(subTime)
    i+=1
    tripTimes.append(t2-t1)
#print(tripTimes)
#print(len(tripTimes))
i=0
dictKeys = []
while i < len(toBeKeyOfMonths):
    key = toBeKeyOfMonths[i][0] #for i, _ in enumerate(toBeKeyOfMonths)
    #print(i)
    #print(key)
    dictKeys.append(key)
    i+=1
#print(dictKeys)
i=0
dictValues = []
while i < len(tripTimes):
    value = tripTimes[i][0]
    #print(i)
    #print(value)
    dictValues.append(value)
    i+=1
#print(dictValues)

# %%
# Get pairs of elements
zip_iterator = zip(dictKeys, dictValues)
# Convert to dictionary
daysInMonths = dict(zip_iterator)
print(daysInMonths)
# Out:
# {'7': Timedelta('22 days 03:11:48'), '8': Timedelta('30 days 22:23:01'), '9': Timedelta('29 days 23:40:23'), '10': Timedelta('30 days 23:52:35'), '11': Timedelta('30 days 02:56:48'), '12': Timedelta('30 days 23:55:41'), '1': Timedelta('30 days 23:49:34'), '2': Timedelta('10 days 03:10:11')}

# %%
print(len(daysInMonths))
# Out:
# 8

# %%
dayStr = str(daysInMonths['7'])
org_string = dayStr
size = len(org_string)
# Slice string to remove last 3 characters from string
mod_string = org_string[:size - 9]
print(mod_string)
# Out:
# 22 days

# %%
print(dayStr)
# Out:
# 22 days 03:11:48

# %%
order = daysInMonths.keys()
print(order)
# Out:
# dict_keys(['7', '8', '9', '10', '11', '12', '1', '2'])

# %%
print(str(gpsDfT1['Data Month']))
print(len(gpsDfT1['Data Month']))
# Out:
# 0       7
# 1       7
# 2       7
# 3       7
# 4       7
#        ..
# 3210    2
# 3211    2
# 3212    2
# 3213    2
# 3214    2
# Name: Data Month, Length: 3215, dtype: object
# 3215

# %%
gpsDfT1['Data Month'] = gpsDfT1['Data Month'].astype('str')

print(len(gpsDfT1['Data Month']))

x,y = gpsDfT1['Data Month'], gpsDfT1['Speed km/h']

fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')

scatter1 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], ec='k')
scatter2 = plt.scatter(gpsDfT1['Data Month'], gpsDfT1['Speed km/h'], ec='k')
plt.xlabel('Tracked Months', fontsize=14)
plt.ylabel('Speed (Km/h)', fontsize=14)
plt.ylim(ymin=0, ymax = 4.5)
plt.xlim(xmax = len(daysInMonths))
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x)
y_max = [np.max(y)]*len(x)

# create lines on the graph
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
maxLine = plt.plot(y_max, '-', label="Average Speed", color='red')

# Create legend
meanLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Estimated Average Speed = {round(y.mean(), 2)} km/h')
maxLineLegend = mlines.Line2D(gpsDfT1['Data Month'],y_mean, color='red', marker='_',
                          markersize=15, label=f'Maximum Speed = {round(y.max(), 2)} km/h')

#legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
plt.legend(handles=[meanLineLegend, maxLineLegend], loc=1)
#plt.gca().add_artist(legend1)
title = f"Loggerhead Sea Turtle {tag} Speeds"
titleCont = " in Km/h"

plt.title(title+titleCont, fontdict={'fontsize': 16, 'fontweight': 'medium'}, loc='center')
plt.show()
# Out:
# 3215

# %%
gpsDfT1['Data Month'] = gpsDfT1['Data Month'].astype('str')
i=0
#print(gpsDfT1['Data Month'][0])
newColumnList = []
while i < len(gpsDfT1['Data Month']):
    if gpsDfT1['Data Month'][i] == '7':
        newColumnList.append(f"July 2020")        
    elif gpsDfT1['Data Month'][i] == '8':
        newColumnList.append("August 2020")
    elif gpsDfT1['Data Month'][i] == '9':
        newColumnList.append("September 2020")
    elif gpsDfT1['Data Month'][i] == '10':
        newColumnList.append("October 2020")
    elif gpsDfT1['Data Month'][i] == '11':
        newColumnList.append("November 2020")
    elif gpsDfT1['Data Month'][i] == '12':
        newColumnList.append("December 2020")
    elif gpsDfT1['Data Month'][i] == '1':
        newColumnList.append("January 2021")
    elif gpsDfT1['Data Month'][i] == '2':
        newColumnList.append("February 2021")
    elif gpsDfT1['Data Month'][i] == '3':
        newColumnList.append("March 2021")
    elif gpsDfT1['Data Month'][i] == '4':
        newColumnList.append("April 2021")
    elif gpsDfT1['Data Month'][i] == '5':
        newColumnList.append("May 2021")
    elif gpsDfT1['Data Month'][i] == '6':
        newColumnList.append("June 2021")
    i+=1
print(newColumnList)
gpsDfT1['Months by Year'] = newColumnList
# Out:
# ['July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 2020', 'July 20 ...

# %%
dayStr = str(daysInMonths['7'])
org_string = dayStr
size = len(org_string)
# Slice string to remove last 3 characters from string
mod_string = org_string[:size - 9]
print(mod_string)
# Out:
# 22 days

# %%
#gpsDfT1['Data Month'] = gpsDfT1['Data Month'].astype('str')
i=0
#print(gpsDfT1['Data Month'][0])
newColumnList = []
while i < len(gpsDfT1['Data Month']):
    
    if gpsDfT1['Data Month'][i] == '7':
        dayStr = str(daysInMonths['7'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"July 2020 ({mod_string})")  
    elif gpsDfT1['Data Month'][i] == '8':
        dayStr = str(daysInMonths['8'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"August 2020 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '9':
        dayStr = str(daysInMonths['9'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"September 2020 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '10':
        dayStr = str(daysInMonths['10'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"October 2020 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '11':
        dayStr = str(daysInMonths['11'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"November 2020 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '12':
        dayStr = str(daysInMonths['12'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"December 2020 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '1':
        dayStr = str(daysInMonths['1'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"January 2021 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '2':
        dayStr = str(daysInMonths['2'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"February 2021 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '3':
        dayStr = str(daysInMonths['3'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"March 2021 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '4':
        dayStr = str(daysInMonths['4'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"April 2021 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '5':
        dayStr = str(daysInMonths['5'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"May 2021 ({mod_string})")
    elif gpsDfT1['Data Month'][i] == '6':
        dayStr = str(daysInMonths['6'])
        org_string = dayStr
        size = len(org_string)
        # Slice string to remove last 9 characters from string
        mod_string = org_string[:size - 9]
        #print(mod_string)
        newColumnList.append(f"June 2021 ({mod_string})")
    i+=1
print(newColumnList)
gpsDfT1['Tracked Days by Month'] = newColumnList
# Out:
# ['July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 days)', 'July 2020 (22 
# 4     2020-07-10 18:50:57.619104+00:00          7       2020      July 2020
# ...                                ...        ...        ...            ...
# 3210  2021-02-10 17:12:41.507593+00:00          2       2021  February 2021
# 3211  2021-02-10 17:12:39.588645+00:00          2       2021  February 2021
# 3212  2021-02-11 17:13:45.487280+00:00          2       2021  February 2021
# 3213  2021-02-11 17:13:44.938524+00:00          2       2021  February 2021
# 3214  2021-02-11 17:13:44.977153+00:00          2       2021  February 2021
#
#       Speed km/h    Tracked Days by Month
# 0       0.000000      July 2020 (22 days)
# 1       0.032460      July 2020 (22 days)
# 2       0.160610      July 2020 (22 days)
# 3       0.012875      July 2020 (22 days)
# 4       0.014596      July 2020 (22 days)
# ...          ...                      ...
# 3210    0.563665  February 2021 (10 days)
# 3211    0.547349  February 2021 (10 days)
# 3212    0.419893  February 2021 (10 days)
# 3213    0.249876  February 2021 (10 days)
# 3214    0.186558  February 2021 (10 days)
#
# [3215 rows x 20 columns]

# %%
#gpsDfT1['Data Month'] = gpsDfT1['Data Month'].astype('str')
#i=0
#print(gpsDfT1['Data Month'][0])
#key = list(daysInMonths.keys())[0]

#if gpsDfT1['Data Month'][i] == list(daysInMonths.keys())[i]:
    #gpsDfT1['Data Month'] = gpsDfT1['Data Month'] + list(daysInMonths.keys())[0]
    #print(gpsDfT1['Data Month'])
    #print(i)
    #i+=1
#else:
    #print(gpsDfT1['Data Month'][i])
    #print(list(daysInMonths.keys())[i])

# %%
x,y = gpsDfT1['Tracked Days by Month'], gpsDfT1['Speed km/h']

fig, ax = plt.subplots(num=None, figsize=(20,10), dpi=80, facecolor='w', edgecolor='k')

scatter1 = plt.scatter(gpsDfT1['Tracked Days by Month'], gpsDfT1['Speed km/h'], ec='k')
scatter2 = plt.scatter(gpsDfT1['Tracked Days by Month'], gpsDfT1['Speed km/h'], ec='k')
plt.xlabel('Tracked Months', fontsize=14)
plt.ylabel('Speed (Km/h)', fontsize=14)
plt.ylim(ymin=0, ymax = 4.5)
plt.xlim(xmax = len(daysInMonths))
plt.grid(axis='y', alpha=0.75)

# Calculate the simple average of the data
y_mean = [np.mean(y)]*len(x)
y_max = [np.max(y)]*len(x)

# create lines on the graph
averageLine = plt.plot(y_mean, '-', label="Average Speed", color='green')
maxLine = plt.plot(y_max, '-', label="Average Speed", color='red')

# Create legend
meanLineLegend = mlines.Line2D(gpsDfT1['Tracked Days by Month'],y_mean, color='green', marker='_',
                          markersize=15, label=f'Estimated Average Speed = {round(y.mean(), 2)} km/h')
maxLineLegend = mlines.Line2D(gpsDfT1['Tracked Days by Month'],y_mean, color='red', marker='_',
                          markersize=15, label=f'Maximum Speed = {round(y.max(), 2)} km/h')

#legend1 = plt.legend([scatter1, scatter2], ["Daylight", "Night-time"])
plt.legend(handles=[meanLineLegend, maxLineLegend], loc=1)
#plt.gca().add_artist(legend1)
title = f"Loggerhead Sea Turtle {tag} Speeds"
titleCont = " in Km/h"


plt.title(title+titleCont, fontdict={'fontsize': 16, 'fontweight': 'medium'}, loc='center')
plt.show()
